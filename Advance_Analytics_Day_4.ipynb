# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statistics

# %%
df=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\data set\iris.csv")
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.distplot(df["Sepal.Length"])
# Out:
# C:\Users\patil\AppData\Local\Temp\ipykernel_15196\3146673002.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Sepal.Length"])
# <Axes: xlabel='Sepal.Length', ylabel='Density'>

# %%
sns.distplot(df["Sepal.Width"])
plt.show()
# Out:
# C:\Users\patil\AppData\Local\Temp\ipykernel_15196\3252361561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Sepal.Width"])

# %%
df.plot(kind="scatter",x="Sepal.Length",y="Sepal.Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Scatter Plot")
plt.show()

# %%
sns.regplot(x="Sepal.Length",y="Sepal.Width",data=df)
plt.show()

# %%
g = sns.FacetGrid(df,col="Species")
g.map(plt.hist,"Sepal.Length")
plt.show()

# %%
g = sns.FacetGrid(df,col="Species")
g.map(plt.scatter,"Sepal.Length","Sepal.Width")
plt.show()

# %%
g = sns.FacetGrid(df,col="Species")
g.map(plt.scatter,"Petal.Length","Petal.Width")
plt.show()

# %%
g = sns.FacetGrid(df,row="Species")
g.map(plt.scatter,"Petal.Width","Petal.Length")
plt.show()

# %%
sns.jointplot(x="Sepal.Length", y="Sepal.Width",data=df)
plt.show()

# %%
sns.jointplot(x="Sepal.Length", y="Sepal.Width",data=df,kind="reg")

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df,hue="Species")
plt.show()

# %%
sns.boxplot(data=df.melt(), x='variable',y='value', color='yellow')

# %%
sns.boxplot(df)

# %%
df=pd.DataFrame({
    'a':[1,3,4,6,8],
    'b':[2,3,5,6,8],
    'c':[6,5,4,3,2],
    'd':[5,4,3,4,6]
})
df

# %%
# Using numpy to find Variance
(np.square(df['a']-df['a'].mean())).sum()/(df.shape[0]-1)

# %%
# Using numpy to find Variance
np.var(df[['a','b','c','d']], ddof=1)

# %%
plt.scatter(df["a"],df["b"])
plt.xlabel("a")
plt.ylabel("b")

# %%
plt.scatter(df["c"],df["d"])
plt.xlabel("c")
plt.ylabel("d")

# %% [markdown]
# # Covariance

# %%
# Covariance for a and b
((df["a"] - df["a"].mean()) * (df["b"] - df["b"].mean())).sum() / (df.shape[0] - 1)

# %%
#Using numpy to find Covariance
np.cov(df["a"],df["b"])

# %%
np.cov(df["b"],df["c"])

# %%
def covariance(x,y):
    
    #finding the mean of the series x & y
    mean_x = sum(x)/float(len(x))
    mean_y = sum(y)/float(len(y))
    
    #Substracting mean from the individual elements
    sub_x = [i - mean_x for i in x]
    sub_y = [i - mean_y for i in y]
    
    numerator = sum([sub_x[i]*sub_y[i] for i in range(len(sub_x))])
    denominator = len(x)-1
    
    cov = numerator/denominator
    return cov

x = df["a"]
y = df["b"]

covariance(x,y)

# %%
# Corelation

# %%
df[["b","c"]].corr()

# %%
df["2a"]=df["a"]*2    #multiply the value in 'a' by 2
df["2b"]=df["b"]*2    #multiply the value in 'b' by 2
df[["2a","2b"]].corr()
