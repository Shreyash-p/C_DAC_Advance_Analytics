# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as stats
import statistics

# %% [markdown]
# # 1. Load Car93 Data set

# %%
cars=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\Datasets\Cars93.csv")
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# ...

# %% [markdown]
# # 2 using crosstab for AirBags and Type atrribute

# %%
crosstab_col=pd.crosstab(index=cars['AirBags'],columns=cars['Type'])
crosstab_col
# Out:
# Type                Compact  Large  Midsize  Small  Sporty  Van
# AirBags
# Driver & Passenger        2      4        7      0       3    0
# Driver only               9      7       11      5       8    3
# None                      5      0        4     16       3    6

# %% [markdown]
# # 3. calculate marginal probability for Driver & Passenger,Driver only,None

# %%
from scipy.stats.contingency import margins

# %%
x , y = margins(crosstab_col)

# %%
x
# Out:
# array([[16],
#        [43],
#        [34]], dtype=int64)

# %%
y
# Out:
# array([[16, 11, 22, 21, 14,  9]], dtype=int64)

# %%
mar_prb=[]
for i in x:
    prb = i/sum(x)
    mar_prb.append(prb)
mar_prb
# Out:
# [array([0.17204301]), array([0.46236559]), array([0.3655914])]

# %%
sum(mar_prb)
# Out:
# array([1.])

# %% [markdown]
# # 4. calculate marginal probability for Compact , Large , Midsize , Small , Sporty , Van

# %%
mar_prb=[]
for i in y:
    prb = i/sum(y[0])    # 0^th row of y
    mar_prb.append(prb)
print(mar_prb)


mar_prb=[]
for i in y:
    prb = i/sum(x)    # X only has 0^th index
    mar_prb.append(prb)
print(mar_prb)
# Out:
# [array([0.17204301, 0.11827957, 0.23655914, 0.22580645, 0.15053763,
#        0.09677419])]
# [array([0.17204301, 0.11827957, 0.23655914, 0.22580645, 0.15053763,
#        0.09677419])]

# %%
print(mar_prb)
mar_prb=np.transpose(mar_prb)
print(mar_prb)
sum(mar_prb)
# Out:
# [array([0.17204301, 0.11827957, 0.23655914, 0.22580645, 0.15053763,
#        0.09677419])]
# [[0.17204301]
#  [0.11827957]
#  [0.23655914]
#  [0.22580645]
#  [0.15053763]
#  [0.09677419]]
# array([1.])

# %% [markdown]
# # 5. Load min_telcom Data Set

# %%
min_tel=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\Datasets\mini_telcom.csv")
min_tel
# Out:
#    Gender  TT_gt_100    Response
# 0    male         y   not bought
# 1    male         n   not bought
# 2  female         n   not bought
# 3  female         n   not bought
# 4    male         n   not bought
# 5    male         n   not bought
# 6    male         y       bought
# 7  female         y       bought
# 8  female         n       bought
# 9  female         y       bought

# %% [markdown]
# # 6. Calculate Marginal probability for Gender

# %%
print(min_tel.columns)
crosstab_col=pd.crosstab(index=min_tel['Response '],columns=min_tel['Gender '])
crosstab_col
# Out:
# Index(['Gender ', 'TT_gt_100', 'Response '], dtype='object')
# Gender       female   male
# Response
# bought             3      1
# not bought         2      4

# %%
x , y =margins(crosstab_col)
y
# Out:
# array([[5, 5]], dtype=int64)

# %%
mar_prb=[]
y=y.T    # y.T is used to Transpose y array
for i in y:
    prb=i/sum(y)
    mar_prb.append(prb)
mar_prb
# Out:
# [array([0.5]), array([0.5])]

# %% [markdown]
# # 7. calculate the Marginal Probability for bought and not bought

# %%
mar_prb=[]
for i in x:
    prb=i/sum(x)
    mar_prb.append(prb)
mar_prb
# Out:
# [array([0.4]), array([0.6])]

# %% [markdown]
# # 8. Load Salaries data set

# %%
salaries=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\Datasets\Salaries.csv")
salaries
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %% [markdown]
# # 9. create cross tab on discipline and rank

# %%
crosstab_col=pd.crosstab(salaries['discipline'] , salaries['rank'])
crosstab_col
# Out:
# rank        AssocProf  AsstProf  Prof
# discipline
# A                  26        24   131
# B                  38        43   135

# %% [markdown]
# # 10. Calculate conditional probability of AssocProf for each rank

# %%
# To calculate conditional probability we use iloc for specific location
val=crosstab_col.iloc[0,0]
col=crosstab_col.iloc[:,0].values.sum()
v1=val/col
v1
# Out:
# 0.40625

# %%
val=crosstab_col.iloc[1,0]
col=crosstab_col.iloc[:,0].values.sum()
v2=val/col
v2
# Out:
# 0.59375

# %%
v1+v2
# Out:
# 1.0

# %% [markdown]
# # 11. load the HR_comma_sep data set

# %%
HR=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\Datasets\HR_comma_sep.csv")
HR
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...
