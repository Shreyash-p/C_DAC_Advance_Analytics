# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statistics

# %%
iris=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\data set\iris.csv")
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
count=iris["Species"].value_counts()
count
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %%
count.plot(kind="bar",color=["red","orange","blue"])
plt.title("Bar Chart")
plt.ylabel("Count")
plt.xlabel("Species")
plt.show()

# %%
orders=pd.read_csv(r"C:\Users\patil\Desktop\Know IT CADC\Adv Analytics\data set\Orders.csv")
orders
# Out:
#      Order ID Order Date Place of Shipment Payment Terms
# 0   32 90 001  31-Dec-10              Pune        Cheque
# 1   32 90 002   6-Jan-11             Nasik        Online
# 2   32 90 003  14-Jan-11        Ahmednagar          Cash
# 3   32 90 004  18-Feb-11            Nanded        Cheque
# 4   32 90 005  19-Feb-11          Kolhapur          Cash
# ..        ...        ...               ...           ...
# 65  32 90 066  13-Jul-13          Nadurbar        Cheque
# 66  32 90 067  23-Jul-13             Dhule        Cheque
# 67  32 90 068   2-Aug-13         Ratnagiri        Online
# 68  32 90 069   4-Sep-13             Dhule        Cheque
# 69  32 90 070   7-Sep-13         Ratnagiri        Cheque
#
# [70 rows x 4 columns]

# %%
cts=orders["Payment Terms"].value_counts()
cts.plot(kind="bar",color=["red","orange","blue"])
plt.xticks(rotation=45)
plt.show()

# %%
cts=orders["Payment Terms"].value_counts()
cts.plot(kind="pie")
plt.show()

# %%
cts.plot(kind="pie",autopct="%.2f%%")
plt.show()

# %%
# Kernal distribution Estimation plot
iris["Sepal.Length"].plot(kind="kde")
plt.show()

# %%
iris.plot(kind="scatter",x="Sepal.Length",y="Sepal.Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Scatter Plot")
plt.show()

# %%
sns.scatterplot(x="Sepal.Length",y="Sepal.Width",hue="Species",data=iris)
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Scatter Plot")
plt.show()

# %%
sns.countplot(x="Payment Terms",data=orders)
plt.show()

# %%
sns.boxplot(x="Species",y="Sepal.Length",data=iris)
plt.show()
